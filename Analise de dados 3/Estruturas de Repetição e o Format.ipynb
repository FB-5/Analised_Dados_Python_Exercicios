# %%
#percorrer todos os arquivos da pasta base de dados (Pasta Vendas)
import os

# %%
lista_arquivo = os.listdir("/content/drive/MyDrive/Analise de dados 2/Vendas")
print(lista_arquivo)
# Out:
# ['Vendas - Goiás.csv', 'Vendas - Porto Alegre.csv', 'Vendas - Belo Horizonte.csv', 'Vendas - Recife.csv', 'Devolucoes - Goiás.csv', 'Devolucoes - Belo Horizonte.csv', 'Devolucoes - Rio de Janeiro.csv', 'Devolucoes - Curitiba.csv', 'Vendas - Rio de Janeiro.csv', 'Devolucoes - Porto Alegre.csv', 'Vendas - Fortaleza.csv', 'Devolucoes - São Paulo.csv', 'Devolucoes - Fortaleza.csv', 'Vendas - Salvador.csv', 'Devolucoes - Salvador.csv', 'Vendas - São Paulo.csv', 'Devolucoes - Recife.csv', 'Vendas - Curitiba.csv']

# %%
for arquivo in lista_arquivo:
  mes = "fevereiro"
  print(f"/content/drive/MyDrive/Analise de dados 2/Vendas/{mes}/{arquivo}")
# Out:
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Vendas - Goiás.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Vendas - Porto Alegre.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Vendas - Belo Horizonte.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Vendas - Recife.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Devolucoes - Goiás.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Devolucoes - Belo Horizonte.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Devolucoes - Rio de Janeiro.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Devolucoes - Curitiba.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Vendas - Rio de Janeiro.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Devolucoes - Porto Alegre.csv
# /content/drive/MyDrive/Analise de dados 2/Vendas/fevereiro/Vendas - Fortaleza.csv
# ...
